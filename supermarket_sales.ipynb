# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\lenovo\\Downloads\\supermarketsales\\train.csv")
print(df)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#print total number of customers in supermarket visited
print("the num of customers visited=",df.shape[0])
# Out:
# the num of customers visited= 9800

# %%
#top 5 customers
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
#botom 5
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
#Get Information About Our Dataset Like Total Number Rows, Total Number of Columns,
#Datatypes of Each Column And  Memory Requirement.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
#Find Shape of Our Dataset
print("The Shape of Our Dataset=",df.shape)
# Out:
# The Shape of Our Dataset= (9800, 18)

# %%
#Get the Statistical Information about
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
#for all  Descriptive statistics information about Columns
df.describe(include="all")
# Out:
#              Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# count   9800.000000            9800        9800        9800            9800
# unique          NaN            4922        1230        1326               4
# top             NaN  CA-2018-100111  05/09/2017  26/09/2018  Standard Class
# freq            NaN              14          38          34            5859
# mean    4900.500000             NaN         NaN         NaN             NaN
# std     2829.160653             NaN         NaN         NaN             NaN
# min        1.000000             NaN         NaN         NaN             NaN
# 25%     2450.750000             NaN         NaN         NaN             NaN
# 50%     4900.500000             NaN         NaN         NaN             NaN
# 75%     7350.250000             NaN         NaN         NaN             NaN
# max     9800.000000             NaN         NaN         NaN             NaN
#
# ...

# %%
#group by for Category
gby=df.groupby("Category")
print(type(gby))
print("conent of gby=",gby)
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# conent of gby= <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001F89917F3B0>

# %%
#get number of Categories
df.groupby('Category').nunique()
# Out:
#                  Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Category
# Furniture          2078      1727         877        949          4
# Office Supplies    5909      3676        1143       1242          4
# Technology         1813      1519         819        870          4
#
#                  Customer ID  Customer Name  Segment  Country  City  State  \
# Category
# Furniture                705            705        3        1   365     48
# Office Supplies          787            787        3        1   481     48
# Technology               684            684        3        1   340     46
#
#                  Postal Code  Region  Product ID  Sub-Category  Product Name  \
# Category
# Furniture                445       4         375             4           380
# Office Supplies          573       4        1082             9          1057
# Technology               414       4         404             4           412
#
#                  Sales
# Category
# ...

# %%
#get the all first in the Categories
gby.first()
# Out:
#                  Row ID        Order ID  Order Date   Ship Date  \
# Category
# Furniture             1  CA-2017-152156  08/11/2017  11/11/2017
# Office Supplies       3  CA-2017-138688  12/06/2017  16/06/2017
# Technology            8  CA-2015-115812  09/06/2015  14/06/2015
#
#                       Ship Mode Customer ID    Customer Name    Segment  \
# Category
# Furniture          Second Class    CG-12520      Claire Gute   Consumer
# Office Supplies    Second Class    DV-13045  Darrin Van Huff  Corporate
# Technology       Standard Class    BH-11710  Brosina Hoffman   Consumer
#
#                        Country         City       State  Postal Code Region  \
# Category
# Furniture        United States    Henderson    Kentucky      42420.0  South
# Office Supplies  United States  Los Angeles  California      90036.0   West
# Technology       United States  Los Angeles  California      90032.0   West
#
#                       Product ID Sub-Category  \
# Category
# ...

# %%
#get the all last in the Categories
gby.last()
# Out:
#                  Row ID        Order ID  Order Date   Ship Date  \
# Category
# Furniture          9793  CA-2015-127166  21/05/2015  23/05/2015
# Office Supplies    9797  CA-2016-128608  12/01/2016  17/01/2016
# Technology         9800  CA-2016-128608  12/01/2016  17/01/2016
#
#                       Ship Mode Customer ID     Customer Name    Segment  \
# Category
# Furniture          Second Class    KH-16360  Katherine Hughes   Consumer
# Office Supplies  Standard Class    CS-12490  Cindy Schnelling  Corporate
# Technology       Standard Class    CS-12490  Cindy Schnelling  Corporate
#
#                        Country     City  State  Postal Code   Region  \
# Category
# Furniture        United States  Houston  Texas      77070.0  Central
# Office Supplies  United States   Toledo   Ohio      43615.0     East
# Technology       United States   Toledo   Ohio      43615.0     East
#
#                       Product ID Sub-Category  \
# Category
# ...

# %%
#gt the size of Category
df.groupby("Category").size()
# Out:
# Category
# Furniture          2078
# Office Supplies    5909
# Technology         1813
# dtype: int64

# %%
y = category_sales.values
gnames = category_sales.index.tolist()
ev = [0.1 if g == max_category else 0 for g in gnames]
clsm = ['gold', 'lightcoral', 'lightskyblue']  # Example colors

# Plot Pie Chart with style similar to given example
plt.figure(figsize=(8, 8))
plt.pie(
    y,
    labels=gnames,
    explode=ev,
    shadow=True,
    colors=clsm,
    autopct='%0.2f%%',
    wedgeprops={'linewidth': 3, 'edgecolor': 'k'}
)
plt.legend(title='Categories')
plt.title("Sales Distribution by Category", color="g")
plt.savefig("D:\\Matplotlib\\Sales_By_Category.jpeg")
plt.show()
